# %% [markdown]
# # Flitre coordonnees

# %%
plot_events = read_catalog(
    archive;
    start = start_time ,
    stop = end_time ,
    predicate =events ->
        !ismissing(events.latitude) && 
        !ismissing(events.longitude) && 
        lat_min <= events.latitude <= lat_max && 
        lon_min <= events.longitude <= lon_max
)

# %% [markdown]
# # Filtre profondeur + latitude + magnitude

# %%
plot_events = read_catalog(
    archive;
    start = start_time,
    stop = end_time,
    predicate =events ->
        !ismissing(events.depth_km) && 
        !ismissing(events.longitude) &&
        !ismissing(events.latitude) &&
        !ismissing(events.magnitude) && 
        min_depth <= events.depth_km <= max_depth && 
        lon_min <= events.longitude <= lon_max &&
        magnitude_min <= events.magnitude <= magnitude_max && 
        lat_min <= events.latitude <= lat_max
)
# Out:
# UndefVarError: `start_time` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Downloads/sonifSismo.jl-main/notebooks/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W3sZmlsZQ==.jl:1

# %% [markdown]
# # Filtre magnitude

# %%
plot_events = read_catalog(
    archive;
    start = start_time,
    stop = end_time,
    predicate =events ->
        !ismissing(events.magnitude) && 
        !ismissing(events.longitude) && 
        magnitude_min <= events.magnitude <= magnitude_max && 
        lon_min <= events.longitude <= lon_max
)
# Out:
# UndefVarError: `start_time` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Downloads/sonifSismo.jl-main/notebooks/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W5sZmlsZQ==.jl:1
