# %% [markdown]
# # Reading mseed using SeimicIO.jl

# %% [markdown]
# ## loading modules

# %%
using Pkg
using Metal

cd(@__DIR__)
Pkg.activate("../")

# %% [markdown]
# ## need to change the local path to the seed data

# %% [markdown]
# dir="/Users/nobuaki/Documents/mtFujiContinuous"
